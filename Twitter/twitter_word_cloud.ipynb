# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
df = pd.read_csv('twitter_data.csv')
df.tail()
# Out:
#       Unnamed: 0                       Date  \
# 4222        4222  2023-03-04 00:15:19+00:00
# 4223        4223  2023-03-04 00:08:41+00:00
# 4224        4224  2023-03-04 00:08:41+00:00
# 4225        4225  2023-03-04 00:01:38+00:00
# 4226        4226  2023-03-04 00:00:27+00:00
#
#                                      User  \
# 4222    https://twitter.com/Crypto_B_News
# 4223   https://twitter.com/Brick_bi_Brick
# 4224   https://twitter.com/Brick_bi_Brick
# 4225  https://twitter.com/ClickCapital_io
# 4226     https://twitter.com/WayofWisdom1
#
#                                                 Content
# 4222  #Microsoft $MSFT social engagements measured h...
# 4223  My plan…\n\nEvery quarter a share of $AAPL, $T...
# 4224  1 share of $APPL\n1 share of $TSLA\n4 shares o...
# 4225  Will the market rally continue into next week?...
# 4226  “Happiness is found in doing, not merely posse...

# %%
counter = 0
for x in df['Content'].isnull():
    if x:
        df.drop(counter, inplace=True)
    counter = counter + 1

# %%
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import nltk
from nltk.corpus import stopwords
# Create stopword list:
stopwords = set(STOPWORDS)
stopwords.update(["br", "href", "https", "discord", "RAYXtrades", "co", "t",
                  "AMZN", "AAPL", "MSFT", "TSLA", "SPY", "QQQ", "BA", "BABA", "SPX", "META"])
textt = " ".join(review for review in df.Content)
wordcloud = WordCloud(stopwords=stopwords).generate(textt)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.savefig('wordcloud11.png')
plt.show()
